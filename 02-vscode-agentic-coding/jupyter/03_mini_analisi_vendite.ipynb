# %% [markdown]
# # Livello 5 — Mini analisi “da report” (progetto medio)
#
# Stesso dataset di `02_dati_tabella.ipynb`, ma qui ti chiediamo un **filo narrativo**: domanda → codice → figura → conclusione.
#
# ## Domande guida (obbligatorie)
#
# 1. Qual è il **prodotto** con maggior fatturato complessivo (`importo_totale`)?
# 2. Quale **cliente** ha speso di più in totale?
# 3. C’è un **giorno** con fatturato anomalo rispetto agli altri? (anche solo confronto visivo)
#
# ## Consegna
#
# - Ogni risposta: **almeno una cella codice** + **una cella Markdown** che spiega in italiano chiaro.
# - **Due figure** diverse (es. barre + linea o torta + barre orizzontali).
# - Chiedi all’agente di revisionare **solo** le celle Markdown per chiarezza, poi rileggi tu.
#
# ---
# *Percorso CSV (come nel notebook 02):* `../data/vendite_esempio.csv`

# %% [markdown]
# ## Preparazione dati
#
# Carica il CSV, crea `importo_totale`, controlla tipi e valori mancanti.

# %%
# TODO
pass

# %% [markdown]
# ### Risposta 1 — Prodotto top per fatturato
#
# (testo dopo aver calcolato)

# %%
# TODO
pass

# %% [markdown]
# ### Risposta 2 — Cliente che ha speso di più
#
# (testo dopo aver calcolato)

# %%
# TODO
pass

# %% [markdown]
# ### Risposta 3 — Andamento temporale / giorni
#
# (testo + interpretazione)

# %%
# TODO: aggregazione per data e grafico
pass

# %%
# TODO: seconda figura a scelta (deve essere diversa dalla precedente)
pass

# %% [markdown]
# ## Sintesi finale (5–8 righe)
#
# Cosa emergerebbe da questi dati se li presentassi a un committente? Cosa **non** puoi concludere con certezza dal campione piccolo?
