# %% [markdown]
# # Livello 3 — La tua prima notebook
#
# **Obiettivo:** capire celle Markdown vs codice, esecuzione, e come chiedere all’agente spiegazioni mirate.
#
# **Ambiente:** VS Code/Cursor con estensione Jupyter, oppure Jupyter Lab.
#
# 1. Esegui la cella sotto (▶ o `Shift+Invio`).
# 2. Chiedi all’agente: *"Spiega riga per riga l’output della cella precedente senza cambiare il codice."*
# 3. Modifica `nome` e riesegui.

# %%
nome = "studente"
print(f"Ciao, {nome}! Questa è la cella 1.")
print("Somma:", sum(range(1, 6)))

# %% [markdown]
# ## Mini-esercizio
#
# Aggiungi **una nuova cella di codice** sotto questa (usa l’interfaccia o chiedi all’agente come fare nel tuo editor).
#
# La cella deve:
# - leggere da tastiera un numero intero `n`;
# - stampare i quadrati da `1²` a `n²`.
#
# *Suggerimento per l’agente:* "Aggiungi in questo notebook una cella Python che …" citando questo file.
