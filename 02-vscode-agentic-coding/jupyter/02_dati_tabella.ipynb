# %% [markdown]
# # Livello 4 — Dati tabellari (pandas)
#
# **Prerequisito:** `pip install -r requirements-jupyter.txt` (meglio in un virtualenv).
#
# Il CSV si trova in `../data/vendite_esempio.csv` (percorso relativo alla cartella `jupyter/`).
#
# Usa l’agente con vincoli espliciti, ad esempio: *"Usa pandas, niente seaborn, commenta solo le parti non ovvie."*

# %%
from pathlib import Path

import pandas as pd

csv_path = Path("..") / "data" / "vendite_esempio.csv"
df = pd.read_csv(csv_path)
df.head()

# %%
# TODO: colonna importo_totale = quantita * prezzo_unitario
pass

# %%
# TODO: totale importo per categoria (groupby o equivalente)
pass

# %%
import matplotlib.pyplot as plt

# TODO: un grafico a barre: categoria sull'asse x, somma importo_totale sull'asse y
pass
