# %% [markdown]
# # Livello 3+ — Playground numerico
#
# Qui l’agente è utile per **spezzare** un problema in celle: esplora, poi consolidi.
#
# **Consegna:** completare le celle `TODO` e scrivere in Markdown (ultima cella) due frasi su cosa hai osservato.

# %%
import math

numeri = [12, 7, 19, 3, 11]
numeri

# %%
# TODO: media aritmetica di `numeri` senza usare statistiche esterne (solo sum/len)
pass

# %%
# TODO: lista dei numeri maggiori della media calcolata sopra
pass

# %% [markdown]
# ### Osservazioni (scrivi qui)
#
# -
# -
