# %% [markdown]
# # Soluzione es06 febbre ipossia

# %%
from pathlib import Path
import pandas as pd

csv_path = Path('..') / 'data' / 'vitali_pazienti.csv'
df = pd.read_csv(csv_path)
df.head()

# %%
df.loc[(df['temperatura'] >= 37.5) & (df['spo2'] < 95), ['id','temperatura','spo2']]
