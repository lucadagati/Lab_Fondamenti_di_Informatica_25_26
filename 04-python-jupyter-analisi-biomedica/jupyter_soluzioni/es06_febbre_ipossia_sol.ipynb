# %% [markdown]
# # Esercizio 6 - Febbre e ipossia
# Soluzione semplificata con passaggi espliciti.

# %%
from pathlib import Path
import pandas as pd

# Carichiamo il dataset
csv_path = Path('..') / 'data' / 'vitali_pazienti.csv'
df = pd.read_csv(csv_path)
df.head()

# %%
# Condizione doppia: febbre AND ipossia
cond = (df['temperatura'] >= 37.5) & (df['spo2'] < 95)
df[cond][['id', 'temperatura', 'spo2']]
