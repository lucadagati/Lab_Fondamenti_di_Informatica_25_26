# %% [markdown]
# # Esercizio 4 - Conteggio ipertesi

# %%
from pathlib import Path
import pandas as pd

# Carichiamo il dataset
csv_path = Path('..') / 'data' / 'vitali_pazienti.csv'
df = pd.read_csv(csv_path)
df.head()

# %%
# Conteggio righe con sistolica alta
ipertesi = df[df['sistolica'] >= 140]
print('Pazienti con sistolica >= 140:', len(ipertesi))
