# %% [markdown]
# # Soluzione es04 conta ipertesi

# %%
from pathlib import Path
import pandas as pd

csv_path = Path('..') / 'data' / 'vitali_pazienti.csv'
df = pd.read_csv(csv_path)
df.head()

# %%
conteggio = (df['sistolica'] >= 140).sum()
print('Pazienti con sistolica >= 140:', int(conteggio))
