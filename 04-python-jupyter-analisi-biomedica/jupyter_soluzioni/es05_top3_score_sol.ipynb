# %% [markdown]
# # Soluzione Esercizio 5 - Tuple e ordinamento

# %%
coppie=[('Luca',3),('Anna',1),('Marta',2)]
ordinate=sorted(coppie, key=lambda t: t[1])
print(ordinate)
print([nome for nome,_ in ordinate])
