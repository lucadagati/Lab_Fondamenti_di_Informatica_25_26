# %% [markdown]
# # Soluzione es03 medie parametri

# %%
from pathlib import Path
import pandas as pd

csv_path = Path('..') / 'data' / 'vitali_pazienti.csv'
df = pd.read_csv(csv_path)
df.head()

# %%
df[['bpm','spo2','sistolica']].mean()
