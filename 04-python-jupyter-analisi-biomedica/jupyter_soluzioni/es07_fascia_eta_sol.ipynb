# %% [markdown]
# # Soluzione es07 fascia eta

# %%
from pathlib import Path
import pandas as pd

csv_path = Path('..') / 'data' / 'vitali_pazienti.csv'
df = pd.read_csv(csv_path)
df.head()

# %%
df.loc[(df['eta'] >= 50) & (df['eta'] <= 75), ['id','eta']]
