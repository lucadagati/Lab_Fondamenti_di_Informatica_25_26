# %% [markdown]
# # Esercizio 3 - While e validazione

# %%
# TODO: imposta n = -2 e valida con while finché n > 0
# TODO: quando valido, stampa 1..n con while
# TODO: mostra il valore finale di n
pass
