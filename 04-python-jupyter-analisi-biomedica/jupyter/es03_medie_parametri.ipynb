# %% [markdown]
# # Medie parametri vitali\n\nCompleta le celle TODO.\n

# %%
from pathlib import Path\nimport pandas as pd\n\ncsv_path = Path('..') / 'data' / 'vitali_pazienti.csv'\ndf = pd.read_csv(csv_path)\ndf.head()

# %%
# TODO: calcola media bpm\npass

# %%
# TODO: calcola media spo2\npass

# %%
# TODO: calcola media sistolica\npass
