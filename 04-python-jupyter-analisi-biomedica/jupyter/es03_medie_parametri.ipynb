# %% [markdown]
# # Esercizio 3 - While validazione
# Notebook esercizio con passi guidati.

# %%
# TODO: valida n con while finche non e positivo
# TODO: usa un secondo while per stampare 1..n
# TODO: mostra output finale
pass
