# %% [markdown]
# # Esercizio 1 - Classifica voto

# %%
# TODO: definisci classifica_voto(voto)
# TODO: testa la funzione su [15, 22, 27, 30]
# TODO: stampa risultato in formato 'voto -> classe'
pass
