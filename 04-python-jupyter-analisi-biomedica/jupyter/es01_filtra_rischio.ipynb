# %% [markdown]
# # Filtro pazienti a rischio\n\nCompleta le celle TODO.\n

# %%
from pathlib import Path\nimport pandas as pd\n\ncsv_path = Path('..') / 'data' / 'vitali_pazienti.csv'\ndf = pd.read_csv(csv_path)\ndf.head()

# %%
# TODO: carica ../data/vitali_pazienti.csv in un DataFrame\npass

# %%
# TODO: crea la colonna flag_rischio con OR su bpm/spo2/sistolica\npass

# %%
# TODO: mostra solo gli ID a rischio\npass
