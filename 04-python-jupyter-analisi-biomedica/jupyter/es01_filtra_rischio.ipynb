# %% [markdown]
# # Esercizio 1 - Classifica voto
# Notebook esercizio con passi guidati.

# %%
# TODO: definisci la funzione classifica_voto(voto)
# TODO: usa if/elif/else per i quattro intervalli richiesti
# TODO: testa la funzione su voti di esempio e stampa risultato
pass
