# %% [markdown]
# # Esercizio 4 - Stringhe vocali
# Notebook esercizio con passi guidati.

# %%
# TODO: implementa funzione conta_vocali
# TODO: usa ciclo su testo.lower()
# TODO: testa la funzione su una frase
pass
