# %% [markdown]
# # Conteggio ipertesi\n\nCompleta le celle TODO.\n

# %%
from pathlib import Path\nimport pandas as pd\n\ncsv_path = Path('..') / 'data' / 'vitali_pazienti.csv'\ndf = pd.read_csv(csv_path)\ndf.head()

# %%
# TODO: filtra pazienti con sistolica >= 140\npass

# %%
# TODO: conta i pazienti filtrati\npass

# %%
# TODO: stampa il conteggio\npass
