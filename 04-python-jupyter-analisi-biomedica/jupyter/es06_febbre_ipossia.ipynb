# %% [markdown]
# # Febbre + ipossia\n\nCompleta le celle TODO.\n

# %%
from pathlib import Path\nimport pandas as pd\n\ncsv_path = Path('..') / 'data' / 'vitali_pazienti.csv'\ndf = pd.read_csv(csv_path)\ndf.head()

# %%
# TODO: filtra temperatura >= 37.5\npass

# %%
# TODO: filtra spo2 < 95\npass

# %%
# TODO: mostra id dei pazienti che soddisfano entrambe\npass
