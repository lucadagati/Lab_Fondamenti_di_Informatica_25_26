# %% [markdown]
# # Esercizio 6 - Dizionario frequenze
# Notebook esercizio con passi guidati.

# %%
# TODO: costruisci dizionario frequenze caratteri
# TODO: ignora gli spazi
# TODO: stampa dizionario finale
pass
