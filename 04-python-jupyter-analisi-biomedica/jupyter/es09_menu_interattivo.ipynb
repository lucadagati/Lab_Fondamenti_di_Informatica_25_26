# %% [markdown]
# # Menu interattivo\n\nCompleta le celle TODO.\n

# %%
from pathlib import Path\nimport pandas as pd\n\ncsv_path = Path('..') / 'data' / 'vitali_pazienti.csv'\ndf = pd.read_csv(csv_path)\ndf.head()

# %%
# TODO: crea ciclo while per menu testuale\npass

# %%
# TODO: gestisci scelta 1 (conteggio rischio)\npass

# %%
# TODO: gestisci scelta 2 (media bpm) e scelta 0 (esci)\npass
