# %% [markdown]
# # Esercizio 9 - Menu while
# Notebook esercizio con passi guidati.

# %%
# TODO: simula scelte con for su lista di input
# TODO: gestisci 1/2/0 con if-elif
# TODO: stampa azioni
pass
