# %% [markdown]
# # Classificazione pressione\n\nCompleta le celle TODO.\n

# %%
from pathlib import Path\nimport pandas as pd\n\ncsv_path = Path('..') / 'data' / 'vitali_pazienti.csv'\ndf = pd.read_csv(csv_path)\ndf.head()

# %%
# TODO: crea funzione classe_pressione(sistolica)\npass

# %%
# TODO: applica funzione alla colonna sistolica\npass

# %%
# TODO: mostra id, sistolica, classe_pressione\npass
