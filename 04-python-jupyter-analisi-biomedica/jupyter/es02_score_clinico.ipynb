# %% [markdown]
# # Esercizio 2 - Somma media massimo
# Notebook esercizio con passi guidati.

# %%
# TODO: inizializza somma e massimo
# TODO: esegui ciclo for per aggiornare le variabili
# TODO: calcola media e stampa risultati
pass
