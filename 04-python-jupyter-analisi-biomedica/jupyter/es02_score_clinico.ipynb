# %% [markdown]
# # Score clinico\n\nCompleta le celle TODO.\n

# %%
from pathlib import Path\nimport pandas as pd\n\ncsv_path = Path('..') / 'data' / 'vitali_pazienti.csv'\ndf = pd.read_csv(csv_path)\ndf.head()

# %%
# TODO: calcola score_clinico per ogni riga\npass

# %%
# TODO: crea colonna classe_rischio (Basso/Medio/Alto)\npass

# %%
# TODO: mostra tabella con id, score_clinico, classe_rischio\npass
