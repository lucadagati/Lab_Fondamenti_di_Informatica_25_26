# %% [markdown]
# # Top 3 score rischio\n\nCompleta le celle TODO.\n

# %%
from pathlib import Path\nimport pandas as pd\n\ncsv_path = Path('..') / 'data' / 'vitali_pazienti.csv'\ndf = pd.read_csv(csv_path)\ndf.head()

# %%
# TODO: crea score_clinico\npass

# %%
# TODO: ordina DataFrame per score_clinico decrescente\npass

# %%
# TODO: mostra top 3 con id e score_clinico\npass
