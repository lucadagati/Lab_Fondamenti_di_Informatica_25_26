# %% [markdown]
# # Esercizio 5 - Tuple ordinamento esplicito
# Notebook esercizio con passi guidati.

# %%
# TODO: ordina una lista di tuple con algoritmo esplicito
# TODO: non usare lambda/sorted
# TODO: stampa risultato
pass
