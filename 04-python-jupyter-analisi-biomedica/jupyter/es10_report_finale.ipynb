# %% [markdown]
# # Esercizio 10 - Analisi parole
# Notebook esercizio con passi guidati.

# %%
# TODO: costruisci dizionario frequenze parole
# TODO: calcola totale parole
# TODO: trova parola più frequente
pass
