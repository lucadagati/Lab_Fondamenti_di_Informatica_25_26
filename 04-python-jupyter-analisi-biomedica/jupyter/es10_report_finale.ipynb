# %% [markdown]
# # Report clinico finale\n\nCompleta le celle TODO.\n

# %%
from pathlib import Path\nimport pandas as pd\n\ncsv_path = Path('..') / 'data' / 'vitali_pazienti.csv'\ndf = pd.read_csv(csv_path)\ndf.head()

# %%
# TODO: calcola totale pazienti\npass

# %%
# TODO: calcola numero pazienti rischio alto\npass

# %%
# TODO: trova paziente con score massimo e stampa report\npass
