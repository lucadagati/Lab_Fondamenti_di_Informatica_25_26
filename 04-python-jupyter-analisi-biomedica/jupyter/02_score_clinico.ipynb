# %% [markdown]
# # Notebook 2 - Score clinico e grafico\n\nObiettivo: calcolare score rischio e visualizzare distribuzione classi.

# %%
from pathlib import Path\nimport pandas as pd\nimport matplotlib.pyplot as plt\n\ncsv_path = Path('..') / 'data' / 'vitali_pazienti.csv'\ndf = pd.read_csv(csv_path)\ndf.head()

# %%
# TODO: calcola score clinico riga per riga con regole del file es02\npass

# %%
# TODO: crea colonna 'classe_rischio' (Basso/Medio/Alto)\npass

# %%
# TODO: grafico a barre con conteggio pazienti per classe_rischio\npass
