# %% [markdown]
# # Notebook 1 - Esplorazione dati vitali\n\nObiettivo: caricare `../data/vitali_pazienti.csv` e rispondere a domande semplici sui dati.

# %%
from pathlib import Path\nimport pandas as pd\n\ncsv_path = Path('..') / 'data' / 'vitali_pazienti.csv'\ndf = pd.read_csv(csv_path)\ndf.head()

# %%
# TODO: quanti pazienti hanno bpm >= 100?\npass

# %%
# TODO: mostra id e spo2 dei pazienti con spo2 < 95\npass

# %%
# TODO: crea una colonna 'flag_rischio' (True/False) con le regole:\n# bpm >= 100 OR spo2 < 95 OR sistolica >= 140\npass
