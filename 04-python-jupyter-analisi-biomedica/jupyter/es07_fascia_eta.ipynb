# %% [markdown]
# # Esercizio 7 - Filtri con for
# Notebook esercizio con passi guidati.

# %%
# TODO: crea lista filtrati con ciclo for
# TODO: crea lista quadrati con altro ciclo for
# TODO: stampa entrambe
pass
